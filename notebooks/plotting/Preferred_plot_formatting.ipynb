# %% [markdown]
# ## This notebook serves as a repository for the code I like to use to produce my preferred plot aesthetic

# %% [markdown]
# ### Import settings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns
sns.set_style('white')
params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Axes

# %%
'''
ax.tick_params(axis='x', which='major', reset=True, top=False, labelsize=12)
ax.tick_params(axis='y', which='major', reset=True, right=False, labelsize=12)

for spine in ['left','bottom']:
    ax.spines[spine].set_linewidth(2)

'''
# Out:
# "\nax.tick_params(axis='x', which='major', reset=True, top=False, labelsize=12)\nax.tick_params(axis='y', which='major', reset=True, right=False, labelsize=12)\n\nfor spine in ['left','bottom']:\n    ax.spines[spine].set_linewidth(2)\n\n"

# %% [markdown]
# ### Colors

# %%
'''
image_colors = ['#c5cae9', '#ffcdd2', '#c8e6c9', '#ffe0b2',
 '#e1bee7', '#d7ccc8', '#cfd8dc', '#b2ebf2']
 
 
SUPERFICIAL_COLOR = "#eaa186"
DEEP_COLOR = "#4379bc"
GRAY = "#777777"
LIGHT_GRAY = "#d9d9d9"
CHARCOAL = "#2d2926"

NAVY = "#003057"
BLUE = "#2A7DE2"
PEACH = "#EBA287"
GRAY = "#737373"
LIGHT_GRAY = "#D9D9D9"
DMD_COLORS = {1: BLUE, 2: PEACH}
'''
# Out:
# '\nimage_colors = [\'#c5cae9\', \'#ffcdd2\', \'#c8e6c9\', \'#ffe0b2\',\n \'#e1bee7\', \'#d7ccc8\', \'#cfd8dc\', \'#b2ebf2\']\n \n \nSUPERFICIAL_COLOR = "#eaa186"\nDEEP_COLOR = "#4379bc"\nGRAY = "#777777"\nLIGHT_GRAY = "#d9d9d9"\nCHARCOAL = "#2d2926"\n'
