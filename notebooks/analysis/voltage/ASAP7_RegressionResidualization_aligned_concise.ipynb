# %% [markdown]
# # ASAP7 regression residualization — aligned session-time version
#
# This notebook is intentionally short. The helper module `asap7_regression_tools.py` handles the verbose alignment, loading, and regression functions.
#
# **Time convention used throughout**
#
# All streams are mapped onto **session-relative HARP seconds**:
#
# ```text
# session_time_sec = absolute_harp_time - first_encoder_harp_time
# ```
#
# For the session files you attached, this gives:
#
# - encoder/running: starts at `0 s`
# - imaging epoch: starts at `~6.386656 s`
# - image/change/omission onsets from voltage QC: already session-relative
# - voltage H5 timebase: auto-detected as either session-relative or imaging-relative and corrected accordingly

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# Put asap7_regression_tools.py next to this notebook.
if str(Path.cwd()) not in sys.path:
    sys.path.insert(0, str(Path.cwd()))

import vip_slap2_analysis.voltage.asap7_regression_tools as ar

plt.rcParams["figure.dpi"] = 120
pd.set_option("display.max_columns", 80)

import warnings
from vip_slap2_analysis.io.session_registry import VIPSessionRegistry
from vip_slap2_analysis.utils.utils import save_figure
from IPython.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
warnings.filterwarnings("default")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def plot_r2_summary_fixed(r2_df):
    order = [m for m in ["drift", "drift_running", "drift_stimulus", "full"]
             if m in set(r2_df["model"])]
    dmds = sorted(r2_df["dmd"].unique())

    fig, ax = plt.subplots(figsize=(9, 4))

    x = np.arange(len(order))
    width = 0.8 / max(1, len(dmds))

    for j, dmd_name in enumerate(dmds):
        vals = [
            r2_df.loc[
                (r2_df["dmd"] == dmd_name) & (r2_df["model"] == model_name),
                "r2"
            ].to_numpy(dtype=float)
            for model_name in order
        ]

        means = [np.nanmean(v) if len(v) else np.nan for v in vals]
        sems = [
            np.nanstd(v, ddof=1) / np.sqrt(max(np.isfinite(v).sum(), 1))
            if np.isfinite(v).sum() > 1 else 0
            for v in vals
        ]

        xpos = x - 0.4 + width / 2 + j * width

        ax.bar(
            xpos,
            means,
            width=width,
            yerr=sems,
            capsize=3,
            alpha=0.8,
            label=dmd_name,
        )

        for i, v in enumerate(vals):
            if len(v) == 0:
                continue
            jitter = np.linspace(-0.25 * width, 0.25 * width, len(v))
            ax.plot(
                np.full(len(v), xpos[i]) + jitter,
                v,
                "o",
                ms=3,
                alpha=0.55,
            )

    ax.set_xticks(x)
    ax.set_xticklabels(order, rotation=30, ha="right")
    ax.set_ylabel("Held-out R²")
    ax.set_title("Regression model performance by DMD")
    ax.legend(frameon=False)
    ax.spines[["top", "right"]].set_visible(False)

    plt.tight_layout()
    return fig, ax


# Monkey-patch the helper module for this notebook session.
ar.plot_r2_summary = plot_r2_summary_fixed

# %%
# %matplotlib inline

# %% [markdown]
# ## Load the data asset objects

# %%
today_str = datetime.today().strftime('%Y-%m-%d')

BASE_PATH = Path(r'\\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics')
SAVE_PATH = Path(r'C:\Users\andrew.shelton\Dropbox\allen institute\Documents\Presentations\OPhys\Lab_Meetings\2026-07-28_OPhys_LabMeetingV\figures\voltage_plots')

TARGET_MICE = [
    826031,
    826032
]

PARADIGMS = ["change_detection_passive"]
EXCLUDE_SESSION_TYPES = ["expression_check", "volume_imaging"]

# Voltage extraction writes files like:
#   voltage_session_traces_dff_robust_f0_trial.h5
# This variant controls the filename suffix. The plotted dataset is SIGNAL below.
TRACE_VARIANT = "dff_robust_f0_trial"
SIGNAL = "dff"      # one of: "raw_f", "f0", "dff"

# Optional direct override. Leave as None to resolve from asset.derived_dir / "voltage".
SESSION_TRACE_H5 = None

# %%
registry = VIPSessionRegistry.from_basepath(BASE_PATH)

process_df = registry.sessions(
    subject_ids=TARGET_MICE,
    exclude_session_types=EXCLUDE_SESSION_TYPES,
    paradigms=PARADIGMS,
)

assets = [registry.resolve_assets(row) for _, row in process_df.iterrows()]

print(f"Found {len(assets)} candidate sessions.")
display(process_df)
# Out:
# Found 19 candidate sessions.
#                     session_id  subject_id  session_# session_date indicator1  \
# 0   826031_2026-01-30_15-04-02      826031          2   2026-01-30     ASAP7y
# 1   826031_2026-02-01_11-01-50      826031          3   2026-02-01     ASAP7y
# 2   826031_2026-02-02_10-23-53      826031          4   2026-02-02     ASAP7y
# 3   826031_2026-02-03_14-21-45      826031          5   2026-02-03     ASAP7y
# 4   826031_2026-02-04_12-15-34      826031          6   2026-02-04     ASAP7y
# 5   826031_2026-02-05_09-28-56      826031          7   2026-02-05     ASAP7y
# 6   826031_2026-02-06_10-21-20      826031          8   2026-02-06     ASAP7y
# 7   826031_2026-02-10_10-48-51      826031          9   2026-02-10     ASAP7y
# 8   826031_2026-02-11_12-42-21      826031         10   2026-02-11     ASAP7y
# 9   826031_2026-02-12_07-43-37      826031         11   2026-02-12     ASAP7y
# 10  826032_2026-01-29_12-59-37      826032          2   2026-01-29     ASAP7y
# 11  826032_2026-01-30_16-31-08      826032          3   2026-01-30     ASAP7y
# 12  826032_2026-02-02_08-24-52      826032          4   2026-02-02     ASAP7y
# 13  826032_2026-02-03_16-02-38      826032          5   2026-02-03     ASAP7y
# 14  826032_2026-02-04_13-49-07      826032          6   2026-02-04     ASAP7y
# 15  826032_2026-02-05_13-18-03      826032          7   2026-02-05     ASAP7y
# 16  826032_2026-02-06_11-45-33      826032          8   2026-02-06     ASAP7y
# 17  826032_2026-02-10_13-02-11      826032          9   2026-02-10     ASAP7y
# 18  826032_2026-02-11_14-46-30      826032         10   2026-02-11     ASAP7y
#
#    indicator2 dmd1_depth dmd2_depth                  paradigm session_type  \
# 0         NaN         50        250  change_detection_passive     familiar
# 1         NaN         50        250  change_detection_passive     familiar
# 2         NaN         50        250  change_detection_passive     familiar
# 3         NaN         50        250  change_detection_passive     familiar
# 4         NaN         50        250  change_detection_passive     familiar
# 5         NaN         50        250  change_detection_passive     familiar
# 6         NaN         50        250  change_detection_passive     familiar
# 7         NaN         50        250  change_detection_passive        novel
# 8         NaN         50        250  change_detection_passive       novel+
# 9         NaN         50        250  change_detection_passive       novel+
# 10        NaN         50        250  change_detection_passive     familiar
# 11        NaN         50        250  change_detection_passive     familiar
# 12        NaN         50        250  change_detection_passive     familiar
# 13        NaN         50        250  change_detection_passive     familiar
# 14        NaN         50        250  change_detection_passive     familiar
# 15        NaN         50        250  change_detection_passive     familiar
# 16        NaN         50        250  change_detection_passive     familiar
# 17        NaN         50        250  change_detection_passive        novel
# 18        NaN         50        250  change_detection_passive       novel+
#
#     stimulus    experimentor instrument_name instrument_id camera_type  \
# 0   images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 1   images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 2   images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 3   images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 4   images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 5   images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 6   images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 7    image_B  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 8    image_B  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 9    image_B  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 10  images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 11  images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 12  images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 13  images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 14  images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 15  images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 16  images_A  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 17   image_B  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
# 18   image_B  Andrew Shelton    slap2_albert       SLAP2_1   spinnaker
#
#    has raster ROI? has integration roi? behavior_rig quality flags  \
# 0              yes                  yes        VCO.1    good   NaN
# 1              yes                  yes        VCO.1    good   NaN
# 2              yes                  yes        VCO.1    good   NaN
# 3              yes                  yes        VCO.1    good   NaN
# 4              yes                  yes        VCO.1    good   NaN
# 5              yes                  yes        VCO.1    good   NaN
# 6              yes                  yes        VCO.1    good   NaN
# 7              yes                  yes        VCO.1    good   NaN
# 8              yes                  yes        VCO.1    good   NaN
# 9              yes                  yes        VCO.1    good   NaN
# 10             yes                  yes        VCO.1    good   NaN
# 11             yes                  yes        VCO.1    good   NaN
# 12             yes                  yes        VCO.1    good   NaN
# 13             yes                  yes        VCO.1    good   NaN
# 14             yes                  yes        VCO.1    good   NaN
# 15             yes                  yes        VCO.1    good   NaN
# 16             yes                  yes        VCO.1    good   NaN
# 17             yes                  yes        VCO.1    good   NaN
# 18             yes                  yes        VCO.1    good   NaN
#
#                                           session_dir  purpose notes
# 0   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 1   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 2   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 3   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 4   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 5   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 6   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 7   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 8   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 9   \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 10  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 11  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 12  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 13  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 14  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 15  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 16  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 17  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN
# 18  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...      NaN   NaN

# %% [markdown]
# ## 1. Configuration
#
# Use `assets[SESSION_INDEX]` when available. Manual paths override asset-derived paths and are useful for debugging.

# %%
SESSION_INDEX = 0

# Leave these as None when using your normal `assets` object.
MANUAL_TRACE_H5 = None
MANUAL_QC_DIR = None
MANUAL_ENCODER_PKL = None
MANUAL_HARP_DF_CSV = None
MANUAL_BONSAI_EVENT_LOG_CSV = None

# Voltage/session trace configuration.
TRACE_VARIANT = "dff_robust_f0_trial"
SIGNAL_NAME = "dff"
REG_TARGET_FS_HZ = 100.0
VALID_ROIS_ONLY = True
MAX_SECONDS = None  # e.g. 300 for a smoke test

# Running-wheel constants.
TICKS_PER_REVOLUTION = 8192
WHEEL_RADIUS_CM = 4.69

# Timebase behavior.
# "auto" should be correct for both session-relative and imaging-relative voltage H5 timebases.
VOLTAGE_TIME_MODE = "auto"

# Event extraction.
EVENT_SOURCE_DMD = "auto"  # uses DMD1 if present

# %% [markdown]
# ## 2. Resolve paths and align behavior/stimulus/imaging
#
# This is the critical alignment section. It should show running from 0 to ~session duration, imaging starting slightly later, and event times overlapping the imaging epoch.

# %%
asset = assets[SESSION_INDEX] if "assets" in globals() else None

paths = ar.resolve_session_paths(
    asset,
    trace_h5=MANUAL_TRACE_H5,
    qc_dir=MANUAL_QC_DIR,
    encoder_pkl=MANUAL_ENCODER_PKL,
    harp_df_csv=MANUAL_HARP_DF_CSV,
    bonsai_event_log_csv=MANUAL_BONSAI_EVENT_LOG_CSV,
    trace_variant=TRACE_VARIANT,
)

display(pd.DataFrame({
    "item": ["trace_h5", "qc_dir", "encoder_pkl", "harp_df_csv", "bonsai_event_log_csv"],
    "path": [paths.trace_h5, paths.qc_dir, paths.encoder_pkl, paths.harp_df_csv, paths.bonsai_event_log_csv],
}))
# Out:
#                    item                                               path
# 0              trace_h5  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...
# 1                qc_dir  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...
# 2           encoder_pkl  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...
# 3           harp_df_csv  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...
# 4  bonsai_event_log_csv  \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...

# %%
ctx = ar.build_timing_context(
    paths,
    ticks_per_revolution=TICKS_PER_REVOLUTION,
    wheel_radius_cm=WHEEL_RADIUS_CM,
    event_source_dmd=EVENT_SOURCE_DMD,
)

summary = ar.alignment_summary_table(ctx)
display(summary)

print("session_harp_t0_abs:", ctx["session_harp_t0_abs"])
print("HARP_df summary:", ctx["harp_summary"])
print("event metadata:", ctx["event_meta"])

ar.assert_timing_alignment(ctx)
print("Alignment checks passed.")
# Out:
#             stream  start_sec      end_sec          n
# 0  encoder/running   0.000000  1800.119008  1800121.0
# 1  imaging_epoch_1   6.386656  1800.115040        NaN
# 2            image   7.141116  1799.141038     2352.0
# 3           change   9.441136  1794.574317      285.0
# 4         omission  88.713513  1758.073337       15.0
# session_harp_t0_abs: 192612.530976
# HARP_df summary: {'first_harp_abs': 192612.531488, 'last_harp_abs': 194412.647008, 'first_session_sec': 0.0005119999987073243, 'last_session_sec': 1800.1160319999908, 'n_rows': 440665}
# event metadata: {'path': '\\\\allen\\aind\\scratch\\ophys\\Andrew\\VIP_synaptic_dynamics\\ASAP7\\826031\\826031_2026-01-30_15-04-02\\analysis\\qc\\voltage\\voltage_extraction_qc_dff_robust_f0_trial.json', 'event_source_dmd': 'DMD1', 'windows_sec_present_but_ignored': True, 'event_counts_in_qc': {'image_total': 2382, 'image_after_epoch_filter': 2352, 'change_total': 286, 'change_after_epoch_filter': 285, 'omission_total': 15, 'omission_after_epoch_filter': 15, 'n_unique_image_ids_total': 7, 'n_unique_image_ids_after_epoch_filter': 7}, 'n_loaded': {'image': 2352, 'change': 285, 'omission': 15}}
# Alignment checks passed.

# %%
# First 90 seconds after imaging onset.
fig, axes = ar.plot_alignment_overview(ctx, duration_sec=1800)
plt.show()

# %% [markdown]
# ## 3. Load voltage on the aligned session timebase
#
# The helper auto-detects whether `timebase_sec` is already session-relative or needs the imaging epoch start added. Inspect `time_mode_used` below. If this is wrong, override with:
#
# ```python
# VOLTAGE_TIME_MODE = "already_session"
# # or
# VOLTAGE_TIME_MODE = "imaging_relative"
# ```

# %%
voltage = ar.load_voltage_lowfreq(
    paths.trace_h5,
    ctx,
    signal_name=SIGNAL_NAME,
    target_fs_hz=REG_TARGET_FS_HZ,
    valid_rois_only=VALID_ROIS_ONLY,
    max_seconds=MAX_SECONDS,
    voltage_time_mode=VOLTAGE_TIME_MODE,
)

rows = []
for dmd, d in voltage["dmd"].items():
    rows.append({
        "dmd": dmd,
        "n_rois": d["X"].shape[0],
        "n_samples": d["X"].shape[1],
        "fs_hz": d["fs_hz"],
        "time_start_sec": float(d["time_sec"][0]),
        "time_end_sec": float(d["time_sec"][-1]),
        "time_mode_used": d["time_mode_used"],
    })
display(pd.DataFrame(rows))
# Out:
#     dmd  n_rois  n_samples       fs_hz  time_start_sec  time_end_sec  \
# 0  DMD1      12     179778  100.225851        6.386656   1800.105469
# 1  DMD2      13     179778  100.225851        6.386656   1800.105469
#
#          time_mode_used
# 0  already_session_auto
# 1  already_session_auto

# %%
# Verify that running interpolates onto voltage time; this should not be empty.
for dmd, d in voltage["dmd"].items():
    rt = ar.interpolate_running_to_time(ctx, d["time_sec"])
    print(dmd, "finite speed fraction:", np.mean(np.isfinite(rt["speed_cm_s"])))
    print(dmd, "median speed:", np.nanmedian(rt["speed_cm_s"]), "cm/s")
# Out:
# DMD1 finite speed fraction: 1.0
# DMD1 median speed: 1.1979151381438475 cm/s
# DMD2 finite speed fraction: 1.0
# DMD2 median speed: 1.1979151381438475 cm/s

# %%
# Visual alignment of voltage population, running, and events over one short window.
dmd0 = sorted(voltage["dmd"].keys())[0]
t = voltage["dmd"][dmd0]["time_sec"]
Xz = ar.robust_zscore_rows(voltage["dmd"][dmd0]["X"])
pop = np.nanmean(Xz, axis=0)
run_t = ar.interpolate_running_to_time(ctx, t)

t0 = max(float(ctx["epochs"]["start_time_sec"].min()), float(t[0])) + 5
t1 = t0 + 120
m = (t >= t0) & (t <= t1)

fig, ax = plt.subplots(figsize=(12, 4))

# Voltage trace
v_lines = ax.plot(
    t[m],
    pop[m],
    lw=1,
    label=f"{dmd0} population voltage",
)

# Running trace on second y-axis
ax2 = ax.twinx()
s_lines = ax2.plot(
    t[m],
    run_t.loc[m, "speed_cm_s"],
    lw=1,
    alpha=0.6,
    label="running speed",color='tab:orange'
)

# Event markers
change_line = None
omission_line = None

for ev in ctx["events"]["change"]:
    if t0 <= ev <= t1:
        change_line = ax.axvline(
            ev,
            ls="--",
            lw=0.8,
            alpha=0.8,
            label="change" if change_line is None else None,color='blue'
        )

for ev in ctx["events"]["omission"]:
    if t0 <= ev <= t1:
        omission_line = ax.axvline(
            ev,
            ls=":",
            lw=1.2,
            alpha=0.9,
            label="omission" if omission_line is None else None,color='red'
        )

ax.set_xlabel("session-relative HARP time (s)")
ax.set_ylabel("population voltage, robust z")
ax2.set_ylabel("running speed (cm/s)")
ax.set_title("Final alignment sanity check")

ax.spines[["top"]].set_visible(False)
ax2.spines[["top"]].set_visible(False)

# Combined legend from both y-axes plus event markers
handles1, labels1 = ax.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()

ax.legend(
    handles1 + handles2,
    labels1 + labels2,
    loc="best",
    frameon=False,
)

plt.show()

# %% [markdown]
# ## 4. Build regression design
#
# Predictors:
#
# - slow drift basis
# - lagged running velocity/speed/acceleration
# - image flash kernels
# - change kernels
# - omission kernels
#
# This first pass uses dense design matrices and in-sample ridge fits for residualization. Treat R² as descriptive, not cross-validated model performance.

# %%
DESIGN_PARAMS = dict(
    n_drift_basis=12,
    running_lags_sec=(-1.0, -0.5, 0.0, 0.5, 1.0),
    event_window=(-0.5, 1.5),
    event_bin_width=0.05,
)

# Use the first DMD timebase for the design. In normal session-long H5s DMDs share time.
t_model = voltage["dmd"][sorted(voltage["dmd"].keys())[0]]["time_sec"]
X_design, design_meta = ar.build_regression_design(t_model, ctx, **DESIGN_PARAMS)

print("Design shape:", X_design.shape)
display(design_meta.groupby("group").size().rename("n_predictors").reset_index())
display(design_meta.head())
# Out:
# Design shape: (179778, 148)
#        group  n_predictors
# 0     change            40
# 1      drift            12
# 2      image            40
# 3  intercept             1
# 4   omission            40
# 5    running            15
#            name      group
# 0     intercept  intercept
# 1  drift_rbf_00      drift
# 2  drift_rbf_01      drift
# 3  drift_rbf_02      drift
# 4  drift_rbf_03      drift

# %% [markdown]
# ## 5. Fit ROI-wise regression models
#
# Models:
#
# - `drift`
# - `drift_running`
# - `drift_stimulus`
# - `full`

# %%
RIDGE_ALPHA = 10.0

fits = {}
for dmd, d in voltage["dmd"].items():
    if not np.allclose(d["time_sec"], t_model, atol=0.5 / d["fs_hz"]):
        raise ValueError(f"{dmd} timebase does not match design timebase.")
    fits[dmd] = ar.fit_ridge_models(
        X_design,
        d["X"],
        design_meta,
        alpha=RIDGE_ALPHA,
    )

r2_df = ar.summarize_r2(fits)
display(r2_df.groupby(["dmd", "model"])["r2"].agg(["count", "mean", "median", "std"]).reset_index())
fig, ax = ar.plot_r2_summary(r2_df)
ax.set_ylabel("In-sample R²")
ax.set_title("Regression model fit by DMD")
plt.show()
# Out:
#     dmd           model  count      mean    median       std
# 0  DMD1           drift     12  0.036763  0.015307  0.031379
# 1  DMD1   drift_running     12  0.045740  0.017847  0.039631
# 2  DMD1  drift_stimulus     12  0.039330  0.018071  0.031043
# 3  DMD1            full     12  0.048136  0.020333  0.039414
# 4  DMD2           drift     13  0.060314  0.048687  0.049051
# 5  DMD2   drift_running     13  0.073261  0.059469  0.055034
# 6  DMD2  drift_stimulus     13  0.062795  0.051413  0.048688
# 7  DMD2            full     13  0.075673  0.062077  0.054615

# %% [markdown]
# ## 6. Inspect residualization in the frequency domain
#
# The main question is whether image-cadence/task-band power and DMD population coherence drop after removing running/stimulus/drift predictors.

# %%
MODEL_FOR_RESIDUALS = "full"

fig, ax = ar.plot_raw_vs_residual_psd(
    voltage,
    fits,
    model=MODEL_FOR_RESIDUALS,
    fmax=1000.0,
    window_sec=256.0,
)
plt.show()

fig, ax = ar.plot_population_coherence_before_after(
    voltage,
    fits,
    model=MODEL_FOR_RESIDUALS,
    fmax=1000.0,
    window_sec=256.0,
)
plt.show()

# %% [markdown]
# ## 7. Save residual outputs
#
# The saved `.npz` includes raw downsampled traces, predictions, residuals, ROI IDs, and aligned session-relative time vectors.

# %%
if asset is not None and getattr(asset, "derived_dir", None) is not None:
    OUT_DIR = Path(asset.derived_dir) / "regression_residuals"
else:
    OUT_DIR = Path("regression_residuals")

out_dir = ar.save_regression_outputs(
    OUT_DIR,
    voltage,
    fits,
    design_meta,
    r2_df,
    model=MODEL_FOR_RESIDUALS,
)
print("Saved:", out_dir)
# Out:
# Saved: \\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\ASAP7\826031\826031_2026-01-30_15-04-02\analysis\derived\regression_residuals

# %% [markdown]
# ### Preliminary interpretation
# On the full continuous voltage traces, slow session-scale fluctuations explain more variance than the current running or stimulus-timing regressors. Running adds a small but real-looking amount. Generic image/change/omission timing adds surprisingly little. The dominant DMD-shared voltage structure therefore is not well explained by this simple linear event-timing model.

# %%
# Quantify incremental R² by ROI and DMD.
wide_r2 = (
    r2_df
    .pivot_table(index=["dmd", "roi_index"], columns="model", values="r2")
    .reset_index()
)

wide_r2["running_delta_vs_drift"] = wide_r2["drift_running"] - wide_r2["drift"]
wide_r2["stimulus_delta_vs_drift"] = wide_r2["drift_stimulus"] - wide_r2["drift"]
wide_r2["full_delta_vs_drift"] = wide_r2["full"] - wide_r2["drift"]
wide_r2["full_delta_vs_drift_running"] = wide_r2["full"] - wide_r2["drift_running"]
wide_r2["full_delta_vs_drift_stimulus"] = wide_r2["full"] - wide_r2["drift_stimulus"]

display(
    wide_r2
    .groupby("dmd")
    [["drift", "running_delta_vs_drift", "stimulus_delta_vs_drift", 
      "full_delta_vs_drift", "full_delta_vs_drift_running"]]
    .agg(["mean", "median", "std"])
)
# Out:
# model     drift                     running_delta_vs_drift            \
#            mean    median       std                   mean    median
# dmd
# DMD1   0.036763  0.015307  0.031379               0.008977  0.004248
# DMD2   0.060314  0.048687  0.049051               0.012946  0.006703
#
# model           stimulus_delta_vs_drift                      \
#             std                    mean    median       std
# dmd
# DMD1   0.009398                0.002567  0.002764  0.000537
# DMD2   0.013522                0.002481  0.002665  0.000685
#
# model full_delta_vs_drift                     full_delta_vs_drift_running  \
#                      mean    median       std                        mean
# dmd
# DMD1             0.011373  0.006420  0.009190                    0.002396
# DMD2             0.015359  0.010192  0.013319                    0.002413
#
# model
#          median       std
# dmd
# DMD1   0.002558  0.000395
# DMD2   0.002429  0.000514
