# %%
import os
from pathlib import Path
from vip_slap2_analysis.utils import directory_manifest as dm

# %%
root_dir = r"\\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\ASAP7\826031\826031_2026-01-30_15-04-02"
out_dir = root_dir+'\ASAP7_manifest.tsv'

# %%
out_dir
# Out:
# '\\\\allen\\aind\\scratch\\ophys\\Andrew\\VIP_synaptic_dynamics\\ASAP7\\826031\\826031_2026-01-30_15-04-02\\ASAP7_manifest.tsv'

# %%
dm.generate_directory_manifest(root=root_dir,out_path=out_dir,include_root=True)
# Out:
# [('.', 'dir'),
#  ('826031_2026-01-30_15-04-02', 'dir'),
#  ('826031_2026-01-30_15-04-02\\behavior', 'dir'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos', 'dir'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\BodyCamera', 'dir'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\BodyCamera\\metadata_dup1.csv',
#   'file'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\BodyCamera\\video_dup1.mp4',
#   'file'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\EyeCamera', 'dir'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\EyeCamera\\metadata.csv',
#   'file'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\EyeCamera\\video.mp4', 'file'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\FaceCamera', 'dir'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\FaceCamera\\metadata.csv',
#   'file'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\FaceCamera\\video.mp4',
#   'file'),
#  ('826031_2026-01-30_15-04-02\\behavior-videos\\launcher_metadata', 'dir'),
# ...
