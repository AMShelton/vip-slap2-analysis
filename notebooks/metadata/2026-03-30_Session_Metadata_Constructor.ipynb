# %%
import os
import glob
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt

from vip_slap2_analysis.glutamate import summary as gs
from vip_slap2_analysis.metadata.build_dataset_quality_overview import (
    build_dataset_quality_overview,
)

sns.set()
sns.set_style('white')
params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# C:\Users\andrew.shelton\AppData\Local\Temp\ipykernel_8260\447993677.py:23: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
dataset_root = Path(r"\\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics")
session_summary_path = dataset_root / "VIP_SD_summary.xlsx"

mouse_ids = [803496,804730,804733,810196,803121,809047,826033,834788,838410]  # replace with whichever mice you want

overview_df = build_dataset_quality_overview(
    dataset_root=dataset_root,
    session_summary_path=session_summary_path,
    mouse_ids=mouse_ids,
    include_expression_checks=False,
    paradigm_filter="change_detection_passive",
)

overview_df.head()
# Out:
#   mouse_id                  session_id session_date  session_number  \
# 0   803121  803121_2025-10-29_11-19-29   2025-10-29               2
# 1   803121  803121_2025-10-30_11-13-32   2025-10-30               3
# 2   803121  803121_2025-10-31_13-05-26   2025-10-31               4
# 3   803121  803121_2025-11-01_19-00-21   2025-11-01               5
# 4   803121  803121_2025-11-05_11-16-57   2025-11-05               6
#
#   indicator1 indicator2 session_type  stimulus quality quality_simple flags  \
# 0  iGluSnFR4     RCaMP3     familiar  images_A    good           good
# 1  iGluSnFR4     RCaMP3     familiar  images_A    good           good
# 2  iGluSnFR4     RCaMP3     familiar  images_A    good           good
# 3  iGluSnFR4     RCaMP3        novel  images_B    good           good
# 4  iGluSnFR4     RCaMP3       novel+  images_B    good           good
#
#   notes                                        session_dir
# 0        \\allen\aind\scratch\ophys\Andrew\VIP_synaptic...
# ...

# %%
overview_df
# Out:
#    mouse_id                  session_id session_date  session_number  \
# 0    803121  803121_2025-10-29_11-19-29   2025-10-29               2
# 1    803121  803121_2025-10-30_11-13-32   2025-10-30               3
# 2    803121  803121_2025-10-31_13-05-26   2025-10-31               4
# 3    803121  803121_2025-11-01_19-00-21   2025-11-01               5
# 4    803121  803121_2025-11-05_11-16-57   2025-11-05               6
# 5    803121  803121_2025-11-06_12-12-23   2025-11-06               7
# 6    803496  803496_2025-07-25_13-02-10   2025-07-25               2
# 7    803496  803496_2025-07-28_08-04-39   2025-07-28               3
# 8    803496  803496_2025-07-29_13-34-35   2025-07-29               4
# 9    803496  803496_2025-07-30_10-05-23   2025-07-30               5
# 10   803496  803496_2025-07-31_09-43-28   2025-07-31               6
# 11   803496  803496_2025-08-01_13-22-49   2025-08-01               7
# 12   804730  804730_2025-07-25_14-08-35   2025-07-25               2
# ...
